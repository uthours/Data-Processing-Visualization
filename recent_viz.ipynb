# %% [markdown]
# <a href="https://colab.research.google.com/github/uthours/Data-Processing-Visualization/blob/main/recent_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Uttam Subedi
# # Data Processing Visualization
# # Dr. Jacob, ECU 2022
# # Project: Recent Visualization

# %% [markdown]
# ### Topic: Covid-19 Vaccination all over the world

# %% [markdown]
# >**Abstract** This part shows the number of covid-19 cases and number of vaccination given for the top countries. The data is published by informationisbeautiful, it was updated on 04/22/2022. This project contains the info regarding Covid-19 new positive cases, numbers of vaccination given and number of vaccination sold around the world.

# %% [markdown]
# # In 2019, a new coronavirus was identified as the cause of a disease outbreak that originated in China. The virus is now known as the severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2). The disease it causes is called coronavirus disease 2019 (COVID-19). Vaccination process has been started all over the country.

# %% [markdown]
# When I looked into the new daily cases, China has reduced new daily cases by -81.9% while US has reduced to -80.6%. The data shows 88.8% of the population of China are vaccinated. It seems US is still behind than many countries in vaccination with 77% vaccination of the total population. UAE has the most number of vaccinated population with 99% vaccination. The bar represent the total dose given, percentage of vaccinated popularion, % of double vaccinated and % of boosted dose given. This is an excellent visualization which contains many information regarding covid vaccination. I like the part where the number of new corona cases are clearly shown and it also shows update in 1 day and 7 days that's so cool! [link]( https://informationisbeautiful.net/visualizations/covid-19-coronavirus-infographic-datapack/#treatments)

# %% [markdown]
# ![Screenshot (24).png](data:image/png;base64,...)![Screenshot (25).png](data:image/png;base64,...)

# %% [markdown]
# ## Global Covid-19 tracker

# %% [markdown]
# Tableau is a private sales force company. This global tracker, updated daily using data from JHU CSSE COVID-19 Data and The New York Times, comes with a downloadable workbook and starter dashboard. The bar contains the information of new positive covid-19 cases globally from January 21, 2022 to April 29th 2022. I am surprised to see there are more than half million new cases everyday on this day. The number of new cases in Germany is really high(87,298 cases) in comparison to USA while German population is 1/5 in comparison to USA. [Link](https://public.tableau.com/app/profile/covid.19.data.resource.hub/viz/COVID-19Cases_15840488375320/COVID-19GlobalView)

# %% [markdown]
# ![Screenshot (34).png](data:image/png;base64,...)

# %% [markdown]
# ## Tracking Covid-19 Vaccination all around the world
#
# # How many Covid-19 vaccine gas each country brought

# %% [markdown]
# In November 2020, the world received the exciting news that the first COVID-19 vaccines were ready for roll out—and as of now, nearly 7.25 billion doses have been pre-purchased by countries and organizations around the globe. Although high income countries are currently buying the larger shares of doses, India has ordered 1.5 billion—more than any other individual country.
#
# The U.S., in comparison, has pre-purchased 1.01 billion doses, and although this number is less than the amount India has purchased, the U.S. has around 330 million people compared to India’s burgeoning 1.3 billion citizens. As a percentage of total doses sold, high income countries have bought almost 54%, equating to 4 billion doses. Meanwhile, low and middle income countries have purchased just over 23%. This is also a good visualization, the pie chart expains the number of vaccine purchased by countries in numbers and %. I like how thw visualization contains the information of vaccine purchased by countries with high income sources to low income sources. [link](https://www.visualcapitalist.com/tracking-covid-19-vaccines-around-the-world/)

# %% [markdown]
# ![Screenshot (35).png](data:image/png;base64,...)

# %% [markdown]
# #Similarities and differences between the visualizations
#
# 1. First graph shows the information of the nu,ber of vaccinated, % of boosted  population all over the world. It contains horizontal bar graph
#
# 2. Second graph shows the number of new Covid-19 positive cases all over the world. It shows the info in range bar charts.
#
# 3. Third graph shows the number of Covid-19 vaccine purchased by the countries. It shows the info in pie chart.
#
#
# Chile is ranked the highest in % of boosted corona virus in the first graph attached [link]( https://informationisbeautiful.net/visualizations/covid-19-coronavirus-infographic-datapack/#treatments)
# that makes sense when you compare with the second graph I attched below, Chile is ranked at bottom with 2,377 new cases everyday.
#
# India has brought 1.5 billions of Covid-19 vaccine and is able to control new positive cases(3,688 perday) drastically.

# %% [markdown]
# Refrences:
# 1. https://informationisbeautiful.net/visualizations/covid-19-coronavirus-infographic-datapack/#treatments
# 2. https://www.visualcapitalist.com/tracking-covid-19-vaccines-around-the-world/
# 3. https://public.tableau.com/app/profile/covid.19.data.resource.hub/viz/COVID-19Cases_15840488375320/COVID-19GlobalView
# 4. https://ourworldindata.org/grapher/full-list-cumulative-total-tests-per-thousand-bar-chart
