# %% [markdown]
# <a href="https://colab.research.google.com/github/uthours/Data-Processing-Visualization/blob/main/Quiz23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Uttam Subedi

# %% [markdown]
# #Graphical Sophistication
# Find two charts that were not discussed during class today and examine them for graphical excellence, sophistication and integrity. You should write about 100 words about each graph and include the image and a link to where it can be found.

# %% [markdown]
# 1. This research express the report of Ultrasound Attenuation Spectra for Canola Oil. The acoustic attenuation coefficient of liquids and solids is measured experimentally by using the slope method. The acoustic attenuation is plotted against the distance sound propagated.

# %% [markdown]
# https://symposium.foragerone.com/okrd22/presentations/36472
# ![dv5.png](data:image/png;base64,...)

# %% [markdown]
# 2. This presentation provides the information of patient's health. The has used different ECG data to identify heartbeat, the low frequency of anomalous beats and sheer volume of patient data generated in the clinical setting make automated tools for ECG screening appealing. Each method is evaluated on the MIT-BIH Arrhythmia Database. The addition of convolution layers to the vanilla autoencoder does not seem to markedly improve classification process. The RNN perforemed significatnly worse than other two models.

# %% [markdown]
# https://symposium.foragerone.com/okrd22/presentations/37293
# ![dv1.png](data:image/png;base64,...)
