# %% [markdown]
# <a href="https://colab.research.google.com/github/uthours/Data-Processing-Visualization/blob/main/Quiz26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Uttam Subedi

# %% [markdown]
# #Recreate the three boxplots in this lecture using seaborn. Add the jittered points to the final boxplot.

# %%
import pandas as pa
import seaborn  as sns

df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Activity_Dataset_V1.csv')
df.head()
# Out:
#    Unnamed: 0 activity_day    workout_type  distance  time  calories  \
# 0           0   2022-01-01       Freestyle      9.30    77       123
# 1           1   2022-01-01       Freestyle      3.44    96        55
# 2           2   2022-01-01  Indoor Cycling      6.34    85        33
# 3           3   2022-01-01         Walking      7.91    42        82
# 4           4   2022-01-01      Open Water      8.99    36       131
#
#    total_steps  avg_speed  avg_cadence  max_cadence  ... max_pace min_pace  \
# 0          NaN      18.88       168.54       138.30  ...      NaN      NaN
# 1          NaN      29.65       125.92       292.81  ...      NaN      NaN
# 2          NaN      17.85        81.93       323.69  ...      NaN      NaN
# 3       1571.0      22.10        29.63       180.16  ...    28:58    07:58
# 4          NaN      25.83        64.55       342.89  ...      NaN      NaN
#
#   avg_heart_rate  max_heart_rate  min_heart_rate  vo2_max(%)  aerobic(%)  \
# ...

# %% [markdown]
# Recreating boxplots using seaborn

# %%
df.boxplot(column = 'calories',by = 'workout_type')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
ax = sns.boxplot(data = df, x='workout_type', y='calories')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45)
# Out:
# [Text(0, 0, 'Freestyle'),
#  Text(0, 0, 'Indoor Cycling'),
#  Text(0, 0, 'Walking'),
#  Text(0, 0, 'Open Water'),
#  Text(0, 0, 'Outdoor Cycling'),
#  Text(0, 0, 'Outdoor Running'),
#  Text(0, 0, 'Trail Run'),
#  Text(0, 0, 'Pool Swimming'),
#  Text(0, 0, 'Trekking'),
#  Text(0, 0, 'Treadmill'),
#  Text(0, 0, 'Cricket')]

# %% [markdown]
# Multiple violins

# %%
import matplotlib.pyplot as plt

plt.violinplot(df.calories)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7fcc0e868f50>],
#  'cbars': <matplotlib.collections.LineCollection at 0x7fcc0a797a10>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7fcc0e868a50>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7fcc0e868e90>}

# %%
import seaborn as sns

ax = sns.violinplot(data = df, x = 'workout_type', y = 'calories')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45)
ax.set_title('Violin Plot of Calories Burned')
plt.show()
