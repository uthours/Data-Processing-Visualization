# %% [markdown]
# <a href="https://colab.research.google.com/github/uthours/Data-Processing-Visualization/blob/main/Quiz22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Uttam Subedi

# %% [markdown]
#  Head over to Oklahaoma Research Day. Spend some time looking at three posters that include statistical charts or graphs. Include links to each. Discuss the strengths and weaknesses of each. Do they display excellence or do they lie?

# %% [markdown]
# https://symposium.foragerone.com/okrd22/presentations/37192
# ![dv5.png](data:image/png;base64,...)

# %% [markdown]
# Social media is a platform of communication that companies and organizations use to interact with those who are interested in connecting with their certain industry. This research provides the information on social media posts by the Oklahoma Film and Music Organization. They include indigenous communities in film and television. The bar graph includes the data of likes, share, post and comments on different social media platform such as facebook, twitter amd instagram. The indaginous posts have more likes and share in all platforms than regular posts.

# %% [markdown]
# #No.2 link https://symposium.foragerone.com/okrd22/presentations/371944

# %% [markdown]
# ![dv5.png](data:image/png;base64,...)

# %% [markdown]
# The research shows the different sports telecastershow of three ladies. The outcomes will show future female sports telecasters what kind of posts current sports supporters will respond to the most.
#
# 1st graph is a bar chart of the number of posts made in 2021. The X-axis is showing months whereas Y-axis shows the number of posts. I see that the highest number of the post was made in May by Rachel Nichols (around 95-98 posts).
#
# 2nd graph is a simple curve line graph. It seems like Kristen Ledlow is quite inactive on Instagram. Kristen Ledlow’s likes never crossed over 50,000. Megan’s highest like is around 170,000. Rachel Nichols is popular on Instagram.
#
# 3rd graph shows the types of posts made on Instagram individually. Megan mostly got likes on posts about personal lives. Rachel Nichols got the most likes on a post about highly viewed events. I think Kristen got the most likes on the post about with/of Pro athletes and the least likes on the post about advertisements.
