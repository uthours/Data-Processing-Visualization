# %% [markdown]
# <a href="https://colab.research.google.com/github/uthours/Data-Processing-Visualization/blob/main/Quiz22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Uttam Subedi

# %% [markdown]
#  Head over to Oklahaoma Research Day. Spend some time looking at three posters that include statistical charts or graphs. Include links to each. Discuss the strengths and weaknesses of each. Do they display excellence or do they lie?

# %% [markdown]
# One of the intresting research I found was "Comparing the Height and Biomass of Seven Different Forages in Closed Environment" by Zachariah Quetone, Jermaine Berry, and Gilberto Diaz. ![Screenshot (16).png](data:image/png;base64,...)

# %% [markdown]
# Here is the link for the above presentation: https://symposium.foragerone.com/okrd22/presentations/37704

# %% [markdown]
# I like the way how they have came up with amazing idea of using forges to help to reduce environmen temperature. They have used severals tables with differrent data. Overall it was intresting
