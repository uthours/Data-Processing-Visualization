# %% [markdown]
# <a href="https://colab.research.google.com/github/uthours/Data-Processing-Visualization/blob/main/uttamDPVquiz9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dr. Jacob Data Processing Visualization
# # Uttam Subedi

# %% [markdown]
# First thing first, let's import the libraries

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Navigating to Marvel universe wikipedia page to get the table on the films in the Infinity series. https://en.wikipedia.org/wiki/List_of_Marvel_Cinematic_Universe_films

# %%
rawData = requests.get('https://en.wikipedia.org/wiki/List_of_Marvel_Cinematic_Universe_films')
html_parse = raw.text
soup = BeautifulSoup(html_parse,'lxml')

# %% [markdown]
# Let's find the length of the table

# %%
len(soup.find_all('table'))
# Out:
# 7

# %% [markdown]
# Here, I am printing out all the links from the webpage

# %%
marvelTable = soup.find_all('table', class_ = 'wikitable plainrowheaders')
dataf = pd.read_html(str(marvelTable))[0]
dataf
# Out:
#                                    Film  ... Unnamed: 5_level_0
#                            Phase One[2]  ...       Phase One[2]
# 0                              Iron Man  ...                NaN
# 1                   The Incredible Hulk  ...                NaN
# 2                            Iron Man 2  ...                NaN
# 3                                  Thor  ...                NaN
# 4    Captain America: The First Avenger  ...                NaN
# 5                 Marvel's The Avengers  ...                NaN
# 6                          Phase Two[2]  ...       Phase Two[2]
# 7                            Iron Man 3  ...                NaN
# 8                  Thor: The Dark World  ...                NaN
# 9   Captain America: The Winter Soldier  ...                NaN
# 10              Guardians of the Galaxy  ...                NaN
# 11              Avengers: Age of Ultron  ...                NaN
# 12                              Ant-Man  ...                NaN
# ...

# %% [markdown]
# Removing extra rows using droplevel.

# %%
dataf.columns = dataf.columns.droplevel(1)
dataf
# Out:
#                                    Film  ... Unnamed: 5_level_0
# 0                              Iron Man  ...                NaN
# 1                   The Incredible Hulk  ...                NaN
# 2                            Iron Man 2  ...                NaN
# 3                                  Thor  ...                NaN
# 4    Captain America: The First Avenger  ...                NaN
# 5                 Marvel's The Avengers  ...                NaN
# 6                          Phase Two[2]  ...       Phase Two[2]
# 7                            Iron Man 3  ...                NaN
# 8                  Thor: The Dark World  ...                NaN
# 9   Captain America: The Winter Soldier  ...                NaN
# 10              Guardians of the Galaxy  ...                NaN
# 11              Avengers: Age of Ultron  ...                NaN
# 12                              Ant-Man  ...                NaN
# 13                       Phase Three[2]  ...     Phase Three[2]
# ...

# %% [markdown]
# I remove last column "Unnamed: 5_level_0" because it has NaN value alot which doesn't look good in my table.

# %%
del dataf['Unnamed: 5_level_0']
dataf
# Out:
#                                    Film  ...                              Producer(s)
# 0                              Iron Man  ...                 Avi Arad and Kevin Feige
# 1                   The Incredible Hulk  ...  Avi Arad, Gale Anne Hurdand Kevin Feige
# 2                            Iron Man 2  ...                              Kevin Feige
# 3                                  Thor  ...                              Kevin Feige
# 4    Captain America: The First Avenger  ...                              Kevin Feige
# 5                 Marvel's The Avengers  ...                              Kevin Feige
# 6                          Phase Two[2]  ...                             Phase Two[2]
# 7                            Iron Man 3  ...                              Kevin Feige
# 8                  Thor: The Dark World  ...                              Kevin Feige
# 9   Captain America: The Winter Soldier  ...                              Kevin Feige
# ...

# %% [markdown]
# Let's delete row 6 and 13 because it has phase information which are irrevelent.

# %%
dataf.drop([6, 13], inplace = True )
dataf
# Out:
#                                    Film  ...                              Producer(s)
# 0                              Iron Man  ...                 Avi Arad and Kevin Feige
# 1                   The Incredible Hulk  ...  Avi Arad, Gale Anne Hurdand Kevin Feige
# 2                            Iron Man 2  ...                              Kevin Feige
# 3                                  Thor  ...                              Kevin Feige
# 4    Captain America: The First Avenger  ...                              Kevin Feige
# 5                 Marvel's The Avengers  ...                              Kevin Feige
# 7                            Iron Man 3  ...                              Kevin Feige
# 8                  Thor: The Dark World  ...                              Kevin Feige
# 9   Captain America: The Winter Soldier  ...                              Kevin Feige
# 10              Guardians of the Galaxy  ...                              Kevin Feige
# ...

# %% [markdown]
# The indexes are not in right order because I deleted couple rows. I am going to index them again by using reindex_index method.

# %%
dataf = dataf.reset_index(drop=True, inplace=False)
dataf
# Out:
#                                    Film  ...                              Producer(s)
# 0                              Iron Man  ...                 Avi Arad and Kevin Feige
# 1                   The Incredible Hulk  ...  Avi Arad, Gale Anne Hurdand Kevin Feige
# 2                            Iron Man 2  ...                              Kevin Feige
# 3                                  Thor  ...                              Kevin Feige
# 4    Captain America: The First Avenger  ...                              Kevin Feige
# 5                 Marvel's The Avengers  ...                              Kevin Feige
# 6                            Iron Man 3  ...                              Kevin Feige
# 7                  Thor: The Dark World  ...                              Kevin Feige
# 8   Captain America: The Winter Soldier  ...                              Kevin Feige
# 9               Guardians of the Galaxy  ...                              Kevin Feige
# ...
